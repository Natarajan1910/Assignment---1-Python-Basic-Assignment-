# %% [markdown]
# # 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# Answer :
#
# * - Expression
#
# 'hello' - String
#
# -87.8 - Float
#
# - - expression
#
# / - expression
#
# + - expression
#
# 6 - Integer

# %% [markdown]
# # 2. What is the difference between string and variable?
#
# Answers :
#
# A Variable is a store of information, and a String is a type of information you would store in a Variable. A String is usually words, enclosed with ""
#
# Example:
#
# x = "Natarajan"
# X is the Variable, and we declared it as a String, use the single = to assign the text to x variable.

# %% [markdown]
# # 3. Describe three different data types.
#
# Answers :
#
# Int - numbers without decimal
# Float - decimal values
# Boolean - True or False
# String - combination of characters
# List -  Array like structure but you can store any datatype
# Tuple -  Same as list but we cant do changes once its created as it is unmutable
# Set - unique set of array
# Dict - key and value needs to be updated while declaring.

# %% [markdown]
# # 4. What is an expression made up of? What do all expressions do?
#
# Answers :
#
# An expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated. When we run the code in python to print an expression, the interpreter evaluates the expression and displays the result.

# %% [markdown]
# # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Answers:
#
# An expression evaluates to a single value. A statement does not.

# %% [markdown]
# # 6. After running the following code, what does the variable bacon contain?
#
# Answers :
#
# bacon = 22
# bacon + 1
#
# The bacon variable is set to 22. The bacon + 1 expression does not reassign the value in bacon - we will have to put it as x = bacon + 1)

# %% [markdown]
# # 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answers:
#
# Both actions should give the answers as - 'spamspamspam'

# %% [markdown]
# # 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answers :
#
# Because variable names cannot be begin with a number.

# %% [markdown]
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answers :
#
# The int(), float(), and str() functions will evaluate, floating-point number, and string versions of the value should get passed to them.

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Answers :
#
# This expression causes an error because 99 is an integer, and only strings can be concatenated to other strings with the + operator. The correct way can be is I have eaten ' + str(99) + ' burritos and we can ge the answer as = "I have eaten 99 burritos"
